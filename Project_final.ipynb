# %% [markdown]
# <a href="https://colab.research.google.com/github/nualpair/data_viz_2022/blob/main/Project_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Dashboard แสดงผู้ป่วยโควิดกับจำนวนสถานประกอบการในแต่ละจังหวัด**

# %% [markdown]
# ## **Data Preparetion**

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/dataviz_2021_data'
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/dataviz_2021_data
# Out:
# /content/drive/MyDrive/dataviz_2021_data

# %%
data_file_path = os.path.join(path,'covid_1.csv') #นำเข้าข้อมูล
data1 = pd.read_csv(data_file_path)

# %%
data_file_path = os.path.join(path,'covid_2.csv') #นำเข้าข้อมูล
data2 = pd.read_csv(data_file_path)

# %%
data_file_path = os.path.join(path,'covid_3.csv') #นำเข้าข้อมูล
data3 = pd.read_csv(data_file_path)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data_file_path = os.path.join(path,'covid_4.csv') #นำเข้าข้อมูล
data4 = pd.read_csv(data_file_path)

# %%
data1
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1       12/1/20           NaN  หญิง  61.0   ปี       China
# 1            2       17/1/20           NaN  หญิง  74.0   ปี       China
# 2            3       22/1/20           NaN  หญิง  73.0   ปี    Thailand
# 3            4       22/1/20           NaN   ชาย  68.0   ปี       China
# 4            5       24/1/20           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 816984  816985       11/8/21       10/8/21  หญิง   8.0   ปี    Thailand
# 816985  816986       11/8/21       10/8/21   ชาย  14.0   ปี    Thailand
# 816986  816987       11/8/21       10/8/21   ชาย  59.0   ปี    Thailand
# 816987  816988       11/8/21       10/8/21  หญิง  34.0   ปี    Thailand
# 816988  816989       11/8/21       10/8/21  หญิง  19.0   ปี    Thailand
#
#        province_of_isolation  \
# 0              กรุงเทพมหานคร
# 1              กรุงเทพมหานคร
# 2                     นครปฐม
# 3              กรุงเทพมหานคร
# 4                    นนทบุรี
# ...                      ...
# 816984               สระแก้ว
# 816985               สระแก้ว
# 816986               สระแก้ว
# 816987               สระแก้ว
# 816988               สระแก้ว
#
#                                                      risk province_of_onset  \
# 0                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                        คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                                   ...               ...
# 816984                               อยู่ระหว่างการสอบสวน           สระแก้ว
# 816985                               อยู่ระหว่างการสอบสวน           สระแก้ว
# 816986  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...           สระแก้ว
# 816987                                              อื่นๆ     กรุงเทพมหานคร
# 816988                                              อื่นๆ   พระนครศรีอยุธยา
#
#        district_of_onset
# 0                    NaN
# 1                    NaN
# 2                  เมือง
# 3                    NaN
# 4                    NaN
# ...                  ...
# 816984           ตาพระยา
# 816985           ตาพระยา
# 816986        อรัญประเทศ
# 816987       บางขุนเทียน
# 816988             อุทัย
#
# [816989 rows x 11 columns]

# %%
data2
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990       12/8/21       11/8/21   ชาย   7.0   ปี    Thailand
# 1         816991       12/8/21       11/8/21   ชาย   1.0   ปี    Thailand
# 2         816992       12/8/21       11/8/21   ชาย  35.0   ปี    Thailand
# 3         816993       12/8/21       11/8/21  หญิง  33.0   ปี    Thailand
# 4         816994       12/8/21       11/8/21  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153      25/10/21      24/10/21   ชาย  45.0   ปี         NaN
# 1042164  1859154      25/10/21      24/10/21   ชาย  31.0   ปี         NaN
# 1042165  1859155      25/10/21      24/10/21   ชาย  31.0   ปี         NaN
# 1042166  1859156      25/10/21      24/10/21   ชาย  24.0   ปี         NaN
# 1042167  1859157      25/10/21      24/10/21   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# 0                    เชียงราย                                        อื่นๆ
# 1                    เชียงราย                                        อื่นๆ
# 2                    เชียงราย                                        อื่นๆ
# 3                    เชียงราย                                        อื่นๆ
# 4                    เชียงราย  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                          ...
# 1042163         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042164         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042165         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042166         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042167             เชียงใหม่                             ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0                     NaN               NaN
# 1                     NaN               NaN
# 2                     NaN               NaN
# 3                     NaN               NaN
# 4                     NaN               NaN
# ...                   ...               ...
# 1042163               NaN               NaN
# 1042164               NaN               NaN
# 1042165               NaN               NaN
# 1042166               NaN               NaN
# 1042167               NaN               NaN
#
# [1042168 rows x 11 columns]

# %%
data3
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158      26/10/21      25/10/21   ชาย  20.0   ปี    Thailand
# 1        1859159      26/10/21      25/10/21  หญิง  42.0   ปี    Thailand
# 2        1859160      26/10/21      25/10/21  หญิง  33.0   ปี    Thailand
# 3        1859161      26/10/21      25/10/21  หญิง  52.0   ปี    Thailand
# 4        1859162      26/10/21      25/10/21  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612       27/2/22       26/2/22   ชาย   NaN  NaN         NaN
# 1010455  2869613       27/2/22       26/2/22   ชาย   NaN  NaN         NaN
# 1010456  2869614       27/2/22       26/2/22   ชาย   NaN  NaN         NaN
# 1010457  2869615       27/2/22       26/2/22   ชาย   NaN  NaN         NaN
# 1010458  2869616       27/2/22       26/2/22   ชาย   NaN  NaN         NaN
#
#         province_of_isolation                                           risk  \
# 0                       ลำปาง                                          อื่นๆ
# 1                       ลำปาง                                          อื่นๆ
# 2                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4                       ลำปาง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                            ...
# 1010454         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010455         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010456               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010457               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010458               ปัตตานี                               ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset  Unnamed: 11
# 0                   ลำปาง        เมืองลำปาง          NaN
# 1                   ลำปาง        เมืองลำปาง          NaN
# 2                   ลำปาง          ห้างฉัตร          NaN
# 3                   ลำปาง          ห้างฉัตร          NaN
# 4                   ลำปาง        เมืองลำปาง          NaN
# ...                   ...               ...          ...
# 1010454               NaN               NaN          NaN
# 1010455               NaN               NaN          NaN
# 1010456               NaN               NaN          NaN
# 1010457               NaN               NaN          NaN
# 1010458               NaN               NaN          NaN
#
# [1010459 rows x 12 columns]

# %%
data4
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617       28/2/22       27/2/22   ชาย  41.0   ปี    Thailand
# 1       2869618       28/2/22       27/2/22  หญิง  45.0   ปี    Thailand
# 2       2869619       28/2/22       27/2/22  หญิง  40.0   ปี    Thailand
# 3       2869620       28/2/22       27/2/22   ชาย  44.0   ปี    Thailand
# 4       2869621       28/2/22       27/2/22   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165       18/3/22       17/3/22  หญิง   NaN  NaN         NaN
# 433549  3303166       18/3/22       17/3/22  หญิง   NaN  NaN         NaN
# 433550  3303167       18/3/22       17/3/22  หญิง   NaN  NaN         NaN
# 433551  3303168       18/3/22       17/3/22  หญิง   NaN  NaN         NaN
# 433552  3303169       18/3/22       17/3/22  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# 0                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                      ...                                          ...
# 433548         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                             ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                             ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0                  พะเยา        เมืองพะเยา
# 1                  พะเยา        เมืองพะเยา
# 2                  พะเยา        เมืองพะเยา
# 3                  พะเยา        เมืองพะเยา
# 4                  พะเยา        เมืองพะเยา
# ...                  ...               ...
# 433548               NaN               NaN
# 433549               NaN               NaN
# 433550               NaN               NaN
# 433551               NaN               NaN
# 433552               NaN               NaN
#
# [433553 rows x 11 columns]

# %%
data5 = pd.concat([data1 , data2 , data3 , data4]) #รวมตาราง
data5
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1       12/1/20           NaN  หญิง  61.0   ปี       China
# 1             2       17/1/20           NaN  หญิง  74.0   ปี       China
# 2             3       22/1/20           NaN  หญิง  73.0   ปี    Thailand
# 3             4       22/1/20           NaN   ชาย  68.0   ปี       China
# 4             5       24/1/20           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165       18/3/22       17/3/22  หญิง   NaN  NaN         NaN
# 433549  3303166       18/3/22       17/3/22  หญิง   NaN  NaN         NaN
# 433550  3303167       18/3/22       17/3/22  หญิง   NaN  NaN         NaN
# 433551  3303168       18/3/22       17/3/22  หญิง   NaN  NaN         NaN
# 433552  3303169       18/3/22       17/3/22  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 433548         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                  ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset  Unnamed: 11
# 0          กรุงเทพมหานคร               NaN          NaN
# 1          กรุงเทพมหานคร               NaN          NaN
# 2                 นครปฐม             เมือง          NaN
# 3          กรุงเทพมหานคร               NaN          NaN
# 4          กรุงเทพมหานคร               NaN          NaN
# ...                  ...               ...          ...
# 433548               NaN               NaN          NaN
# 433549               NaN               NaN          NaN
# 433550               NaN               NaN          NaN
# 433551               NaN               NaN          NaN
# 433552               NaN               NaN          NaN
#
# [3303169 rows x 12 columns]

# %%
data6 = data5[['announce_date','age','risk','province_of_onset']]
data6
# Out:
#        announce_date   age                              risk province_of_onset
# 0            12/1/20  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1            17/1/20  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2            22/1/20  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3            22/1/20  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4            24/1/20  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...              ...   ...                               ...               ...
# 433548       18/3/22   NaN                  ทัณฑสถาน/เรือนจำ               NaN
# 433549       18/3/22   NaN                  ทัณฑสถาน/เรือนจำ               NaN
# 433550       18/3/22   NaN                  ทัณฑสถาน/เรือนจำ               NaN
# 433551       18/3/22   NaN                  ทัณฑสถาน/เรือนจำ               NaN
# 433552       18/3/22   NaN                  ทัณฑสถาน/เรือนจำ               NaN
#
# [3303169 rows x 4 columns]

# %%
data = [['อำนาจเจริญ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
        ['บึงกาฬ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
        ['บุรีรัมย์','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
        ['ชัยภูมิ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
        ['กาฬสินธุ์','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
        ['ขอนแก่น','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
        ['เลย','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
        ['มหาสารคาม','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
        ['มุกดาหาร','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
        ['นครพนม','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
        ['นครราชสีมา','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
        ['หนองบัวลำภู','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
        ['หนองคาย','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
        ['ร้อยเอ็ด','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
        ['สกลนคร','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
        ['ศรีสะเกษ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
        ['สุรินทร์','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
        ['อุบลราชธานี','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
        ['อุดรธานี','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
        ['ยโสธร','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
        ['เชียงใหม่','เหนือ','เหนือ','เหนือ','เหนือ'],
        ['เชียงราย','เหนือ','เหนือ','เหนือ','เหนือ'],
        ['ลำปาง','เหนือ','เหนือ','เหนือ','เหนือ'],
        ['ลำพูน','เหนือ','เหนือ','เหนือ','เหนือ'],
        ['แม่ฮ่องสอน','เหนือ','เหนือ','เหนือ','เหนือ'],
        ['น่าน','เหนือ','เหนือ','เหนือ','เหนือ'],
        ['พะเยา','เหนือ','เหนือ','เหนือ','เหนือ'],
        ['แพร่','เหนือ','เหนือ','เหนือ','เหนือ'],
        ['อุตรดิตถ์','เหนือ','เหนือ','เหนือ','เหนือ'],
        ['ตาก','ตะวันตก','เหนือ','เหนือ','เหนือ'],
        ['สุโขทัย','กลาง','เหนือ','เหนือ','เหนือ'],
        ['พิษณุโลก','กลาง','เหนือ','เหนือ','เหนือ'],
        ['พิจิตร','กลาง','เหนือ','เหนือ','เหนือ'],
        ['กำแพงเพชร','กลาง','เหนือ','เหนือ','เหนือ'],
        ['เพชรบูรณ์','กลาง','เหนือ','เหนือ','เหนือ'],
        ['นครสวรรค์','กลาง','เหนือ','กลาง','เหนือ'],
        ['อุทัยธานี','กลาง','เหนือ','กลาง','เหนือ'],
        ['อ่างทอง','กลาง','กลาง','กลาง','กลาง'],
        ['ชัยนาท','กลาง','กลาง','กลาง','กลาง'],
        ['พระนครศรีอยุธยา','กลาง','กลาง','กลาง','กลาง'],
        ['กรุงเทพมหานคร','กลาง','กลาง','กลาง','กลาง'],
        ['ลพบุรี','กลาง','กลาง','กลาง','กลาง'],
        ['นครปฐม','กลาง','กลาง','กลาง','กลาง'],
        ['นนทบุรี','กลาง','กลาง','กลาง','กลาง'],
        ['ปทุมธานี','กลาง','กลาง','กลาง','กลาง'],
        ['สมุทรปราการ','กลาง','กลาง','กลาง','กลาง'],
        ['สมุทรสาคร','กลาง','กลาง','กลาง','กลาง'],
        ['สมุทรสงคราม','กลาง','กลาง','กลาง','กลาง'],
        ['สระบุรี','กลาง','กลาง','กลาง','กลาง'],
        ['สิงห์บุรี','กลาง','กลาง','กลาง','กลาง'],
        ['สุพรรณบุรี','กลาง','กลาง','กลาง','กลาง'],
        ['นครนายก','กลาง','กลาง','ตะวันออก','กลาง'],
        ['ฉะเชิงเทรา','ตะวันออก','กลาง','ตะวันออก','ตะวันออก'],
        ['จันทบุรี','ตะวันออก','กลาง','ตะวันออก','ตะวันออก'],
        ['ชลบุรี','ตะวันออก','กลาง','ตะวันออก','ตะวันออก'],
        ['ปราจีนบุรี','ตะวันออก','กลาง','ตะวันออก','ตะวันออก'],
        ['ระยอง','ตะวันออก','กลาง','ตะวันออก','ตะวันออก'],
        ['สระแก้ว','ตะวันออก','กลาง','ตะวันออก','ตะวันออก'],
        ['ตราด','ตะวันออก','กลาง','ตะวันออก','ตะวันออก'],
        ['กาญจนบุรี','ตะวันตก','กลาง','กลาง','กลาง'],
        ['ราชบุรี','ตะวันตก','กลาง','กลาง','กลาง'],
        ['เพชรบุรี','ตะวันตก','กลาง','ใต้ฝั่งตะวันออก','กลาง'],
        ['ประจวบคีรีขันธ์','ตะวันตก','กลาง','ใต้ฝั่งตะวันออก','กลาง'],
        ['ชุมพร','ใต้','ใต้','ใต้ฝั่งตะวันออก','ใต้'],
        ['นครศรีธรรมราช','ใต้','ใต้','ใต้ฝั่งตะวันออก','ใต้'],
        ['นราธิวาส','ใต้','ใต้','ใต้ฝั่งตะวันออก','ใต้'],
        ['ปัตตานี','ใต้','ใต้','ใต้ฝั่งตะวันออก','ใต้'],
        ['พัทลุง','ใต้','ใต้','ใต้ฝั่งตะวันออก','ใต้'],
        ['สงขลา','ใต้','ใต้','ใต้ฝั่งตะวันออก','ใต้'],
        ['สุราษฏร์ธานี','ใต้','ใต้','ใต้ฝั่งตะวันออก','ใต้'],
        ['ยะลา','ใต้','ใต้','ใต้ฝั่งตะวันออก','ใต้'],
        ['กระบี่','ใต้','ใต้','ใต้ฝั่งตะวันตก','ใต้'],
        ['พังงา','ใต้','ใต้','ใต้ฝั่งตะวันตก','ใต้'],
        ['ภูเก็ต','ใต้','ใต้','ใต้ฝั่งตะวันตก','ใต้'],
        ['ระนอง','ใต้','ใต้','ใต้ฝั่งตะวันตก','ใต้'],
        ['สตูล','ใต้','ใต้','ใต้ฝั่งตะวันตก','ใต้'],
        ['ตรัง','ใต้','ใต้','ใต้ฝั่งตะวันตก','ใต้']]
header = ['จังหวัด','ภาค','4 ภูมิภาค(การเมือง)','6 ภูมิภาค(อุตุนิยมวิทยา)','5 ภูมิภาค(การท่องเที่ยว)']

# %%
data7= pd.DataFrame.from_records(data,columns=header)   ## ตารางจังหวัด
data7
# Out:
#        จังหวัด                 ภาค 4 ภูมิภาค(การเมือง)  \
# 0   อำนาจเจริญ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# ..         ...                 ...                 ...
# 72       พังงา                 ใต้                 ใต้
# 73      ภูเก็ต                 ใต้                 ใต้
# 74       ระนอง                 ใต้                 ใต้
# 75        สตูล                 ใต้                 ใต้
# 76        ตรัง                 ใต้                 ใต้
#
#    6 ภูมิภาค(อุตุนิยมวิทยา) 5 ภูมิภาค(การท่องเที่ยว)
# 0        ตะวันออกเฉียงเหนือ       ตะวันออกเฉียงเหนือ
# 1        ตะวันออกเฉียงเหนือ       ตะวันออกเฉียงเหนือ
# 2        ตะวันออกเฉียงเหนือ       ตะวันออกเฉียงเหนือ
# 3        ตะวันออกเฉียงเหนือ       ตะวันออกเฉียงเหนือ
# 4        ตะวันออกเฉียงเหนือ       ตะวันออกเฉียงเหนือ
# ..                      ...                      ...
# 72           ใต้ฝั่งตะวันตก                      ใต้
# 73           ใต้ฝั่งตะวันตก                      ใต้
# 74           ใต้ฝั่งตะวันตก                      ใต้
# 75           ใต้ฝั่งตะวันตก                      ใต้
# 76           ใต้ฝั่งตะวันตก                      ใต้
#
# [77 rows x 5 columns]

# %%
data8 =data6.merge(data7,how='left',left_on='province_of_onset',right_on='จังหวัด')
data8
# Out:
#         announce_date   age                              risk  \
# 0             12/1/20  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1             17/1/20  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2             22/1/20  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3             22/1/20  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4             24/1/20  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...               ...   ...                               ...
# 3303164       18/3/22   NaN                  ทัณฑสถาน/เรือนจำ
# 3303165       18/3/22   NaN                  ทัณฑสถาน/เรือนจำ
# 3303166       18/3/22   NaN                  ทัณฑสถาน/เรือนจำ
# 3303167       18/3/22   NaN                  ทัณฑสถาน/เรือนจำ
# 3303168       18/3/22   NaN                  ทัณฑสถาน/เรือนจำ
#
#         province_of_onset        จังหวัด   ภาค 4 ภูมิภาค(การเมือง)  \
# 0           กรุงเทพมหานคร  กรุงเทพมหานคร  กลาง                กลาง
# 1           กรุงเทพมหานคร  กรุงเทพมหานคร  กลาง                กลาง
# 2                  นครปฐม         นครปฐม  กลาง                กลาง
# 3           กรุงเทพมหานคร  กรุงเทพมหานคร  กลาง                กลาง
# 4           กรุงเทพมหานคร  กรุงเทพมหานคร  กลาง                กลาง
# ...                   ...            ...   ...                 ...
# 3303164               NaN            NaN   NaN                 NaN
# 3303165               NaN            NaN   NaN                 NaN
# 3303166               NaN            NaN   NaN                 NaN
# 3303167               NaN            NaN   NaN                 NaN
# 3303168               NaN            NaN   NaN                 NaN
#
#         6 ภูมิภาค(อุตุนิยมวิทยา) 5 ภูมิภาค(การท่องเที่ยว)
# 0                           กลาง                     กลาง
# 1                           กลาง                     กลาง
# 2                           กลาง                     กลาง
# 3                           กลาง                     กลาง
# 4                           กลาง                     กลาง
# ...                          ...                      ...
# 3303164                      NaN                      NaN
# 3303165                      NaN                      NaN
# 3303166                      NaN                      NaN
# 3303167                      NaN                      NaN
# 3303168                      NaN                      NaN
#
# [3303169 rows x 9 columns]

# %%
data9 = data8[['announce_date','age','risk','ภาค','province_of_onset']]
data9
# Out:
#         announce_date   age                              risk   ภาค  \
# 0             12/1/20  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ  กลาง
# 1             17/1/20  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ  กลาง
# 2             22/1/20  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ  กลาง
# 3             22/1/20  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ  กลาง
# 4             24/1/20  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ  กลาง
# ...               ...   ...                               ...   ...
# 3303164       18/3/22   NaN                  ทัณฑสถาน/เรือนจำ   NaN
# 3303165       18/3/22   NaN                  ทัณฑสถาน/เรือนจำ   NaN
# 3303166       18/3/22   NaN                  ทัณฑสถาน/เรือนจำ   NaN
# 3303167       18/3/22   NaN                  ทัณฑสถาน/เรือนจำ   NaN
# 3303168       18/3/22   NaN                  ทัณฑสถาน/เรือนจำ   NaN
#
#         province_of_onset
# 0           กรุงเทพมหานคร
# 1           กรุงเทพมหานคร
# 2                  นครปฐม
# 3           กรุงเทพมหานคร
# 4           กรุงเทพมหานคร
# ...                   ...
# 3303164               NaN
# 3303165               NaN
# 3303166               NaN
# 3303167               NaN
# 3303168               NaN
#
# [3303169 rows x 5 columns]

# %%
data9.isnull().any() ## ตรวจสอบค่า Missing หลังจากรวมตาราง
# Out:
# announce_date        False
# age                   True
# risk                  True
# ภาค                   True
# province_of_onset     True
# dtype: bool

# %%
data10 = data9.dropna() #แก้Missingด้วยการ Dropan
data10
# Out:
#         announce_date   age                              risk  \
# 0             12/1/20  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1             17/1/20  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2             22/1/20  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3             22/1/20  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4             24/1/20  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...               ...   ...                               ...
# 3303060       18/3/22  11.0                             อื่นๆ
# 3303062       18/3/22  21.0                             อื่นๆ
# 3303063       18/3/22  22.0                             อื่นๆ
# 3303064       18/3/22  25.0                             อื่นๆ
# 3303065       18/3/22  64.0                             อื่นๆ
#
#                         ภาค province_of_onset
# 0                      กลาง     กรุงเทพมหานคร
# 1                      กลาง     กรุงเทพมหานคร
# 2                      กลาง            นครปฐม
# 3                      กลาง     กรุงเทพมหานคร
# 4                      กลาง     กรุงเทพมหานคร
# ...                     ...               ...
# 3303060  ตะวันออกเฉียงเหนือ        นครราชสีมา
# 3303062                กลาง     กรุงเทพมหานคร
# 3303063                กลาง     กรุงเทพมหานคร
# 3303064                กลาง     กรุงเทพมหานคร
# 3303065                กลาง         กำแพงเพชร
#
# [2713977 rows x 5 columns]

# %%
data10.isnull().any()
# Out:
# announce_date        False
# age                  False
# risk                 False
# ภาค                  False
# province_of_onset    False
# dtype: bool

# %%
data10
# Out:
#         announce_date   age                              risk  \
# 0             12/1/20  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1             17/1/20  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2             22/1/20  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3             22/1/20  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4             24/1/20  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...               ...   ...                               ...
# 3303060       18/3/22  11.0                             อื่นๆ
# 3303062       18/3/22  21.0                             อื่นๆ
# 3303063       18/3/22  22.0                             อื่นๆ
# 3303064       18/3/22  25.0                             อื่นๆ
# 3303065       18/3/22  64.0                             อื่นๆ
#
#                         ภาค province_of_onset
# 0                      กลาง     กรุงเทพมหานคร
# 1                      กลาง     กรุงเทพมหานคร
# 2                      กลาง            นครปฐม
# 3                      กลาง     กรุงเทพมหานคร
# 4                      กลาง     กรุงเทพมหานคร
# ...                     ...               ...
# 3303060  ตะวันออกเฉียงเหนือ        นครราชสีมา
# 3303062                กลาง     กรุงเทพมหานคร
# 3303063                กลาง     กรุงเทพมหานคร
# 3303064                กลาง     กรุงเทพมหานคร
# 3303065                กลาง         กำแพงเพชร
#
# [2713977 rows x 5 columns]

# %%
data_file_path = os.path.join(path,'organization - organization.csv') #นำเข้าข้อมูล
data11 = pd.read_csv(data_file_path)

# %%
data11
# Out:
#           จังหวัด สถานประกอบทั้งหมด การผลิต การก่อสร้าง การขนส่งทางบก  \
# 0   กรุงเทพมหานคร           109,664  42,926       5,061         2,883
# 1     สมุทรปราการ            16,459   8,172         659           412
# 2         นนทบุรี            11,933   3,916       1,050           163
# 3        ปทุมธานี            13,155   4,596         919           439
# 4          นครปฐม            10,088   4,486         325           373
# ..            ...               ...     ...         ...           ...
# 72           ตรัง            10,263   3,664         853           461
# 73         พัทลุง            10,295   4,749       1,516           690
# 74        ปัตตานี             6,283   3,067         242           129
# 75           ยะลา             3,431     950         101            50
# 76       นราธิวาส             7,716   2,515         167           192
#
#    ที่พักแรม บริการอาหาร  ศิลปะ
# 0      1,222      54,315  3,257
# 1         67       6,500    649
# 2         82       6,299    423
# 3         86       6,672    443
# 4         69       4,485    350
# ..       ...         ...    ...
# 72       238       4,455    592
# 73       159       2,934    247
# 74        42       2,768     35
# 75        59       2,226     45
# 76        85       4,669     88
#
# [77 rows x 8 columns]

# %%
data11.isnull().any()
# Out:
# จังหวัด              False
# สถานประกอบทั้งหมด    False
# การผลิต              False
# การก่อสร้าง          False
# การขนส่งทางบก        False
# ที่พักแรม            False
# บริการอาหาร          False
# ศิลปะ                False
# dtype: bool

# %%
data12 =data10.merge(data11,how='left',left_on='province_of_onset',right_on='จังหวัด')
data12
# Out:
#         announce_date   age                              risk  \
# 0             12/1/20  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1             17/1/20  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2             22/1/20  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3             22/1/20  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4             24/1/20  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...               ...   ...                               ...
# 2713972       18/3/22  11.0                             อื่นๆ
# 2713973       18/3/22  21.0                             อื่นๆ
# 2713974       18/3/22  22.0                             อื่นๆ
# 2713975       18/3/22  25.0                             อื่นๆ
# 2713976       18/3/22  64.0                             อื่นๆ
#
#                         ภาค province_of_onset        จังหวัด  \
# 0                      กลาง     กรุงเทพมหานคร  กรุงเทพมหานคร
# 1                      กลาง     กรุงเทพมหานคร  กรุงเทพมหานคร
# 2                      กลาง            นครปฐม         นครปฐม
# 3                      กลาง     กรุงเทพมหานคร  กรุงเทพมหานคร
# 4                      กลาง     กรุงเทพมหานคร  กรุงเทพมหานคร
# ...                     ...               ...            ...
# 2713972  ตะวันออกเฉียงเหนือ        นครราชสีมา     นครราชสีมา
# 2713973                กลาง     กรุงเทพมหานคร  กรุงเทพมหานคร
# 2713974                กลาง     กรุงเทพมหานคร  กรุงเทพมหานคร
# 2713975                กลาง     กรุงเทพมหานคร  กรุงเทพมหานคร
# 2713976                กลาง         กำแพงเพชร      กำแพงเพชร
#
#         สถานประกอบทั้งหมด การผลิต การก่อสร้าง การขนส่งทางบก ที่พักแรม  \
# 0                 109,664  42,926       5,061         2,883     1,222
# 1                 109,664  42,926       5,061         2,883     1,222
# 2                  10,088   4,486         325           373        69
# 3                 109,664  42,926       5,061         2,883     1,222
# 4                 109,664  42,926       5,061         2,883     1,222
# ...                   ...     ...         ...           ...       ...
# 2713972            20,396   8,384         912           784       707
# 2713973           109,664  42,926       5,061         2,883     1,222
# 2713974           109,664  42,926       5,061         2,883     1,222
# 2713975           109,664  42,926       5,061         2,883     1,222
# 2713976             6,635   3,249         171           301       137
#
#         บริการอาหาร  ศิลปะ
# 0            54,315  3,257
# 1            54,315  3,257
# 2             4,485    350
# 3            54,315  3,257
# 4            54,315  3,257
# ...             ...    ...
# 2713972       8,841    768
# 2713973      54,315  3,257
# 2713974      54,315  3,257
# 2713975      54,315  3,257
# 2713976       2,552    225
#
# [2713977 rows x 13 columns]

# %%
data12.isnull().any()
# Out:
# announce_date        False
# age                  False
# risk                 False
# ภาค                  False
# province_of_onset    False
# จังหวัด               True
# สถานประกอบทั้งหมด     True
# การผลิต               True
# การก่อสร้าง           True
# การขนส่งทางบก         True
# ที่พักแรม             True
# บริการอาหาร           True
# ศิลปะ                 True
# dtype: bool

# %%
data13 = data12.dropna() #แก้Missingด้วยการ Dropan

print(data13.isnull().any())
print('*'* 100)
data13.head()
# Out:
# announce_date        False
# age                  False
# risk                 False
# ภาค                  False
# province_of_onset    False
# จังหวัด              False
# สถานประกอบทั้งหมด    False
# การผลิต              False
# การก่อสร้าง          False
# การขนส่งทางบก        False
# ที่พักแรม            False
# บริการอาหาร          False
# ศิลปะ                False
# dtype: bool
# ****************************************************************************************************
#   announce_date   age                              risk   ภาค  \
# 0       12/1/20  61.0  คนต่างชาติเดินทางมาจากต่างประเทศ  กลาง
# 1       17/1/20  74.0  คนต่างชาติเดินทางมาจากต่างประเทศ  กลาง
# 2       22/1/20  73.0  คนต่างชาติเดินทางมาจากต่างประเทศ  กลาง
# 3       22/1/20  68.0  คนต่างชาติเดินทางมาจากต่างประเทศ  กลาง
# 4       24/1/20  66.0  คนต่างชาติเดินทางมาจากต่างประเทศ  กลาง
#
#   province_of_onset        จังหวัด สถานประกอบทั้งหมด การผลิต การก่อสร้าง  \
# 0     กรุงเทพมหานคร  กรุงเทพมหานคร           109,664  42,926       5,061
# 1     กรุงเทพมหานคร  กรุงเทพมหานคร           109,664  42,926       5,061
# 2            นครปฐม         นครปฐม            10,088   4,486         325
# 3     กรุงเทพมหานคร  กรุงเทพมหานคร           109,664  42,926       5,061
# 4     กรุงเทพมหานคร  กรุงเทพมหานคร           109,664  42,926       5,061
#
#   การขนส่งทางบก ที่พักแรม บริการอาหาร  ศิลปะ
# 0         2,883     1,222      54,315  3,257
# 1         2,883     1,222      54,315  3,257
# 2           373        69       4,485    350
# 3         2,883     1,222      54,315  3,257
# 4         2,883     1,222      54,315  3,257

# %%
data14 = data13[['age','risk','จังหวัด','ภาค','สถานประกอบทั้งหมด','การผลิต','การก่อสร้าง','การขนส่งทางบก','ที่พักแรม','บริการอาหาร','ศิลปะ']]
data14
# Out:
#           age                              risk        จังหวัด  \
# 0        61.0  คนต่างชาติเดินทางมาจากต่างประเทศ  กรุงเทพมหานคร
# 1        74.0  คนต่างชาติเดินทางมาจากต่างประเทศ  กรุงเทพมหานคร
# 2        73.0  คนต่างชาติเดินทางมาจากต่างประเทศ         นครปฐม
# 3        68.0  คนต่างชาติเดินทางมาจากต่างประเทศ  กรุงเทพมหานคร
# 4        66.0  คนต่างชาติเดินทางมาจากต่างประเทศ  กรุงเทพมหานคร
# ...       ...                               ...            ...
# 2713972  11.0                             อื่นๆ     นครราชสีมา
# 2713973  21.0                             อื่นๆ  กรุงเทพมหานคร
# 2713974  22.0                             อื่นๆ  กรุงเทพมหานคร
# 2713975  25.0                             อื่นๆ  กรุงเทพมหานคร
# 2713976  64.0                             อื่นๆ      กำแพงเพชร
#
#                         ภาค สถานประกอบทั้งหมด การผลิต การก่อสร้าง  \
# 0                      กลาง           109,664  42,926       5,061
# 1                      กลาง           109,664  42,926       5,061
# 2                      กลาง            10,088   4,486         325
# 3                      กลาง           109,664  42,926       5,061
# 4                      กลาง           109,664  42,926       5,061
# ...                     ...               ...     ...         ...
# 2713972  ตะวันออกเฉียงเหนือ            20,396   8,384         912
# 2713973                กลาง           109,664  42,926       5,061
# 2713974                กลาง           109,664  42,926       5,061
# 2713975                กลาง           109,664  42,926       5,061
# 2713976                กลาง             6,635   3,249         171
#
#         การขนส่งทางบก ที่พักแรม บริการอาหาร  ศิลปะ
# 0               2,883     1,222      54,315  3,257
# 1               2,883     1,222      54,315  3,257
# 2                 373        69       4,485    350
# 3               2,883     1,222      54,315  3,257
# 4               2,883     1,222      54,315  3,257
# ...               ...       ...         ...    ...
# 2713972           784       707       8,841    768
# 2713973         2,883     1,222      54,315  3,257
# 2713974         2,883     1,222      54,315  3,257
# 2713975         2,883     1,222      54,315  3,257
# 2713976           301       137       2,552    225
#
# [2713845 rows x 11 columns]

# %%
data14.to_csv('df_data.csv', encoding='utf-8')

# %%
data15 = data14.groupby('จังหวัด').size().reset_index(name='ยอดจำนวนผู้ติดเชื้อ') #ใช้ groupby เผื่อดูจำนวนรวมทั้งหมดของแต่ละจังหวัดในช่วงวันที่ 1 ถึง 4 #เปลี่ยนชื่อคอลัมม์จากเดิมเป็น province_of_isolation เปลี่ยนเป็น ยอดจำนวนผู้ติดเชื้อ
data15
# Out:
#           จังหวัด  ยอดจำนวนผู้ติดเชื้อ
# 0          กระบี่                16085
# 1   กรุงเทพมหานคร               536396
# 2       กาญจนบุรี                23769
# 3       กาฬสินธุ์                17391
# 4       กำแพงเพชร                12473
# ..            ...                  ...
# 71       เพชรบุรี                28065
# 72      เพชรบูรณ์                15895
# 73            เลย                 9696
# 74           แพร่                 4117
# 75     แม่ฮ่องสอน                 3990
#
# [76 rows x 2 columns]
