# %% [markdown]
# <a href="https://colab.research.google.com/github/nualpair/data_viz_2022/blob/main/Project_group_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/dataviz_2021_data'
# Out:
# Mounted at /content/drive

# %%
data_file_path = os.path.join(path,'covid_1.csv') #นำเข้าข้อมูล
data1 = pd.read_csv(data_file_path)

# %%
data_file_path = os.path.join(path,'covid_2.csv') #นำเข้าข้อมูล
data2 = pd.read_csv(data_file_path)

# %%
data_file_path = os.path.join(path,'covid_3.csv') #นำเข้าข้อมูล
data3 = pd.read_csv(data_file_path)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data_file_path = os.path.join(path,'covid_4.csv') #นำเข้าข้อมูล
data4 = pd.read_csv(data_file_path)

# %%
data5 = pd.concat([data1 , data2 , data3 , data4]) #รวมตาราง
data5
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1       12/1/20           NaN  หญิง  61.0   ปี       China
# 1             2       17/1/20           NaN  หญิง  74.0   ปี       China
# 2             3       22/1/20           NaN  หญิง  73.0   ปี    Thailand
# 3             4       22/1/20           NaN   ชาย  68.0   ปี       China
# 4             5       24/1/20           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165       18/3/22       17/3/22  หญิง   NaN  NaN         NaN
# 433549  3303166       18/3/22       17/3/22  หญิง   NaN  NaN         NaN
# 433550  3303167       18/3/22       17/3/22  หญิง   NaN  NaN         NaN
# 433551  3303168       18/3/22       17/3/22  หญิง   NaN  NaN         NaN
# 433552  3303169       18/3/22       17/3/22  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# ...

# %%
data6 = data5[['province_of_onset']]
data6
# Out:
#        province_of_onset
# 0          กรุงเทพมหานคร
# 1          กรุงเทพมหานคร
# 2                 นครปฐม
# 3          กรุงเทพมหานคร
# 4          กรุงเทพมหานคร
# ...                  ...
# 433548               NaN
# 433549               NaN
# 433550               NaN
# 433551               NaN
# 433552               NaN
#
# [3303169 rows x 1 columns]

# %%
data = [['อำนาจเจริญ','ตะวันออกเฉียงเหนือ'],
        ['บึงกาฬ','ตะวันออกเฉียงเหนือ'],
        ['บุรีรัมย์','ตะวันออกเฉียงเหนือ'],
        ['ชัยภูมิ','ตะวันออกเฉียงเหนือ'],
        ['กาฬสินธุ์','ตะวันออกเฉียงเหนือ'],
        ['ขอนแก่น','ตะวันออกเฉียงเหนือ'],
        ['เลย','ตะวันออกเฉียงเหนือ'],
        ['มหาสารคาม','ตะวันออกเฉียงเหนือ'],
        ['มุกดาหาร','ตะวันออกเฉียงเหนือ'],
        ['นครพนม','ตะวันออกเฉียงเหนือ'],
        ['นครราชสีมา','ตะวันออกเฉียงเหนือ'],
        ['หนองบัวลำภู','ตะวันออกเฉียงเหนือ'],
        ['หนองคาย','ตะวันออกเฉียงเหนือ'],
        ['ร้อยเอ็ด','ตะวันออกเฉียงเหนือ'],
        ['สกลนคร','ตะวันออกเฉียงเหนือ'],
        ['ศรีสะเกษ','ตะวันออกเฉียงเหนือ'],
        ['สุรินทร์','ตะวันออกเฉียงเหนือ'],
        ['อุบลราชธานี','ตะวันออกเฉียงเหนือ'],
        ['อุดรธานี','ตะวันออกเฉียงเหนือ'],
        ['ยโสธร','ตะวันออกเฉียงเหนือ'],
        ['เชียงใหม่','เหนือ'],
        ['เชียงราย','เหนือ'],
        ['ลำปาง','เหนือ'],
        ['ลำพูน','เหนือ'],
        ['แม่ฮ่องสอน','เหนือ'],
        ['น่าน','เหนือ'],
        ['พะเยา','เหนือ'],
        ['แพร่','เหนือ'],
        ['อุตรดิตถ์','เหนือ'],
        ['ตาก','ตะวันตก'],
        ['สุโขทัย','กลาง'],
        ['พิษณุโลก','กลาง'],
        ['พิจิตร','กลาง'],
        ['กำแพงเพชร','กลาง'],
        ['เพชรบูรณ์','กลาง'],
        ['นครสวรรค์','กลาง'],
        ['อุทัยธานี','กลาง'],
        ['อ่างทอง','กลาง'],
        ['ชัยนาท','กลาง'],
        ['พระนครศรีอยุธยา','กลาง'],
        ['กรุงเทพมหานคร','กลาง'],
        ['ลพบุรี','กลาง'],
        ['นครปฐม','กลาง'],
        ['นนทบุรี','กลาง'],
        ['ปทุมธานี','กลาง'],
        ['สมุทรปราการ','กลาง'],
        ['สมุทรสาคร','กลาง'],
        ['สมุทรสงคราม','กลาง'],
        ['สระบุรี','กลาง'],
        ['สิงห์บุรี','กลาง'],
        ['สุพรรณบุรี','กลาง'],
        ['นครนายก','กลาง'],
        ['ฉะเชิงเทรา','ตะวันออก'],
        ['จันทบุรี','ตะวันออก'],
        ['ชลบุรี','ตะวันออก'],
        ['ปราจีนบุรี','ตะวันออก'],
        ['ระยอง','ตะวันออก'],
        ['สระแก้ว','ตะวันออก'],
        ['ตราด','ตะวันออก'],
        ['กาญจนบุรี','ตะวันตก'],
        ['ราชบุรี','ตะวันตก',],
        ['เพชรบุรี','ตะวันตก'],
        ['ประจวบคีรีขันธ์','ตะวันตก'],
        ['ชุมพร','ใต้'],
        ['นครศรีธรรมราช','ใต้'],
        ['นราธิวาส','ใต้'],
        ['ปัตตานี','ใต้'],
        ['พัทลุง','ใต้'],
        ['สงขลา','ใต้'],
        ['สุราษฏร์ธานี','ใต้'],
        ['ยะลา','ใต้'],
        ['กระบี่','ใต้'],
        ['พังงา','ใต้'],
        ['ภูเก็ต','ใต้'],
        ['ระนอง','ใต้'],
        ['สตูล','ใต้'],
        ['ตรัง','ใต้']]
header = ['จังหวัด','ภาค']

data7= pd.DataFrame.from_records(data,columns=header)   ## ตารางจังหวัด
data7
# Out:
#        จังหวัด                 ภาค
# 0   อำนาจเจริญ  ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ  ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์  ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ  ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์  ตะวันออกเฉียงเหนือ
# ..         ...                 ...
# 72       พังงา                 ใต้
# 73      ภูเก็ต                 ใต้
# 74       ระนอง                 ใต้
# 75        สตูล                 ใต้
# 76        ตรัง                 ใต้
#
# [77 rows x 2 columns]

# %%
data8 =data6.merge(data7,how='left',left_on='province_of_onset',right_on='จังหวัด')
data8
# Out:
#         province_of_onset        จังหวัด   ภาค
# 0           กรุงเทพมหานคร  กรุงเทพมหานคร  กลาง
# 1           กรุงเทพมหานคร  กรุงเทพมหานคร  กลาง
# 2                  นครปฐม         นครปฐม  กลาง
# 3           กรุงเทพมหานคร  กรุงเทพมหานคร  กลาง
# 4           กรุงเทพมหานคร  กรุงเทพมหานคร  กลาง
# ...                   ...            ...   ...
# 3303164               NaN            NaN   NaN
# 3303165               NaN            NaN   NaN
# 3303166               NaN            NaN   NaN
# 3303167               NaN            NaN   NaN
# 3303168               NaN            NaN   NaN
#
# [3303169 rows x 3 columns]

# %%
print(data8.isnull().any()) ## ตรวจสอบค่า Missing หลังจากรวมตาราง
print('*'* 100)
data9 = data8.dropna() #แก้Missingด้วยการ Dropna
print(data9.isnull().any()) ## ตรวจสอบค่า Missing อีกครั้ง
data9
# Out:
# province_of_onset    True
# จังหวัด              True
# ภาค                  True
# dtype: bool
# ****************************************************************************************************
# province_of_onset    False
# จังหวัด              False
# ภาค                  False
# dtype: bool
#         province_of_onset        จังหวัด                 ภาค
# 0           กรุงเทพมหานคร  กรุงเทพมหานคร                กลาง
# 1           กรุงเทพมหานคร  กรุงเทพมหานคร                กลาง
# 2                  นครปฐม         นครปฐม                กลาง
# 3           กรุงเทพมหานคร  กรุงเทพมหานคร                กลาง
# 4           กรุงเทพมหานคร  กรุงเทพมหานคร                กลาง
# ...                   ...            ...                 ...
# 3303060        นครราชสีมา     นครราชสีมา  ตะวันออกเฉียงเหนือ
# 3303062     กรุงเทพมหานคร  กรุงเทพมหานคร                กลาง
# 3303063     กรุงเทพมหานคร  กรุงเทพมหานคร                กลาง
# 3303064     กรุงเทพมหานคร  กรุงเทพมหานคร                กลาง
# ...

# %%
data10 = data9.groupby('จังหวัด').size().reset_index(name='ยอดจำนวนผู้ติดเชื้อ') #ใช้ groupby เผื่อดูจำนวนรวมทั้งหมดของแต่ละจังหวัดในช่วงวันที่ 1 ถึง 4 #เปลี่ยนชื่อคอลัมม์จากเดิมเป็น province_of_isolation เปลี่ยนเป็น ยอดจำนวนผู้ติดเชื้อ
data10
# Out:
#           จังหวัด  ยอดจำนวนผู้ติดเชื้อ
# 0          กระบี่                17631
# 1   กรุงเทพมหานคร               563732
# 2       กาญจนบุรี                24319
# 3       กาฬสินธุ์                18579
# 4       กำแพงเพชร                13013
# ..            ...                  ...
# 72       เพชรบุรี                30186
# 73      เพชรบูรณ์                18350
# 74            เลย                 9922
# 75           แพร่                 5667
# 76     แม่ฮ่องสอน                 4145
#
# [77 rows x 2 columns]

# %%
data11 =data10.merge(data7,how='right',left_on='จังหวัด',right_on='จังหวัด')
data11
# Out:
#        จังหวัด  ยอดจำนวนผู้ติดเชื้อ                 ภาค
# 0   อำนาจเจริญ                 2990  ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ                 4960  ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์                 7812  ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ                 5015  ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์                18579  ตะวันออกเฉียงเหนือ
# ..         ...                  ...                 ...
# 72       พังงา                11206                 ใต้
# 73      ภูเก็ต                48894                 ใต้
# 74       ระนอง                14683                 ใต้
# 75        สตูล                14173                 ใต้
# 76        ตรัง                22728                 ใต้
#
# [77 rows x 3 columns]

# %%
data_file_path = os.path.join(path,'organization - organization.csv') #นำเข้าข้อมูล
data12 = pd.read_csv(data_file_path)

# %%
data13 =data11.merge(data12,how='right',left_on='จังหวัด',right_on='จังหวัด')
data13
# Out:
#           จังหวัด  ยอดจำนวนผู้ติดเชื้อ   ภาค สถานประกอบทั้งหมด การผลิต  \
# 0   กรุงเทพมหานคร             563732.0  กลาง           109,664  42,926
# 1     สมุทรปราการ             184049.0  กลาง            16,459   8,172
# 2         นนทบุรี             117113.0  กลาง            11,933   3,916
# 3        ปทุมธานี              85542.0  กลาง            13,155   4,596
# 4          นครปฐม              69524.0  กลาง            10,088   4,486
# ..            ...                  ...   ...               ...     ...
# 72           ตรัง              22728.0   ใต้            10,263   3,664
# 73         พัทลุง              24484.0   ใต้            10,295   4,749
# 74        ปัตตานี              54331.0   ใต้             6,283   3,067
# 75           ยะลา              53485.0   ใต้             3,431     950
# 76       นราธิวาส              46389.0   ใต้             7,716   2,515
#
#    การก่อสร้าง การขนส่งทางบก ที่พักแรม บริการอาหาร  ศิลปะ
# ...

# %%
data13.to_csv('covid2022.csv', encoding='utf-8')

# %%
import folium # package สำหรับ visualize interactive map

# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 1.0 MB 24.7 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 45.1 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 215 kB/s
# ...

# %%
import geopandas # For working with geographical data
import pandas as pd

# %%
th_geojson=geopandas.read_file('/content/drive/MyDrive/dataviz_2021_data/thai.json')
th_geojson
# Out:
#                    name                                           geometry
# 0          Mae Hong Son  POLYGON ((98.47780 19.70563, 98.48260 19.66410...
# 1              Chumphon  POLYGON ((99.50343 10.99705, 99.51157 10.86636...
# 2   Nakhon Si Thammarat  POLYGON ((100.12963 7.80172, 100.04457 7.82446...
# 3                Phuket  POLYGON ((98.41863 7.90375, 98.43165 7.91743, ...
# 4             Phang-nga  MULTIPOLYGON (((98.53631 8.11514, 98.60239 8.0...
# ..                  ...                                                ...
# 72        Nakhon Phanom  POLYGON ((104.75791 16.81889, 104.73452 16.804...
# 73             Mukdahan  POLYGON ((104.75791 16.81889, 104.77901 16.704...
# 74           Narathiwat  POLYGON ((101.72350 6.57438, 101.80836 6.46454...
# 75              Pattani  POLYGON ((101.72350 6.57438, 101.67837 6.57712...
# 76            Bueng Kan  POLYGON ((104.20333 18.01864, 104.12468 17.999...
#
# [77 rows x 2 columns]
